# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("haberman.csv")

# %%
df.head()
# Out:
#    30  64   1  1.1
# 0  30  62   3    1
# 1  30  65   0    1
# 2  31  59   2    1
# 3  31  65   4    1
# 4  33  58  10    1

# %%
df.columns = ["patient_age","operation_year","positive_axillary_nodes","survival_status"]

# %%
df.head()
# Out:
#    patient_age  operation_year  positive_axillary_nodes  survival_status
# 0           30              62                        3                1
# 1           30              65                        0                1
# 2           31              59                        2                1
# 3           31              65                        4                1
# 4           33              58                       10                1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 305 entries, 0 to 304
# Data columns (total 4 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   patient_age              305 non-null    int64
#  1   operation_year           305 non-null    int64
#  2   positive_axillary_nodes  305 non-null    int64
#  3   survival_status          305 non-null    int64
# dtypes: int64(4)
# memory usage: 9.7 KB

# %%
df["patient_age"].dtype
# Out:
# dtype('int64')

# %%
df.isnull().sum()
# Out:
# patient_age                0
# operation_year             0
# positive_axillary_nodes    0
# survival_status            0
# dtype: int64

# %%
corr = df.corr()
sns.heatmap(corr, annot = True)
# Out:
# <AxesSubplot:>

# %%
df["operation_year"].nunique()
# Out:
# 12

# %%
##questions to answer:
##1.is the age group and pstv axillary nodes correlated?
##2.does a specific age group have more cances of surviving 
##3.does the operation year have any effect on the survival status
##4.from the heatmap we can observe axillary nodes have a high effect on survival satus

# %%
sns.kdeplot(data=df, x="patient_age", hue="survival_status")
# Out:
# <AxesSubplot:xlabel='patient_age', ylabel='Density'>

# %%
sns.histplot(data = df, x = "patient_age", hue = "survival_status")
# Out:
# <AxesSubplot:xlabel='patient_age', ylabel='Count'>

# %%
## observation from the above 2 plots: ppl bw ages 40 and 60 have a lesser chance of survivng

# %%
sns.catplot(x="operation_year", col="survival_status", data=df, kind="count", palette = "Blues", size = 10)
# Out:
# /Users/jasleengill/opt/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:3750: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.kdeplot(data=df, x="operation_year", hue="survival_status")
# Out:
# <AxesSubplot:xlabel='operation_year', ylabel='Density'>

# %%
##from the above 2 plots we can see that ppl who were operated bw 62 and 65 had a higher chance of dying

# %%
sns.jointplot(data=df, x="patient_age", y="positive_axillary_nodes", hue="survival_status")

# %% [markdown]
# ## 1. number of axillary nodes have high effect on survival
# ## 2. ppl bw ages 40 and 60 have a lesser chance of survivng
# ## 3. ppl who were operated bw 62 and 65 had a higher chance of dying
